# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics

from statsmodels.tsa.seasonal import seasonal_decompose, STL
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# %matplotlib inline

plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %%
curve_df = pd.read_csv('./data/curve.csv', index_col=0)
curve_df['Date'] = pd.to_datetime(curve_df['Date'])
curve_df
# Out:
#           Date     Beta0     Beta1     Beta2       Tau  \
# 0   1985-01-01  0.114743 -0.036232  0.000180  1.000000
# 1   1985-02-01  0.122315 -0.038918  0.003118  1.000000
# 2   1985-03-01  0.119559 -0.039595  0.005560  1.000000
# 3   1985-04-01  0.118350 -0.041404 -0.004642  1.000000
# 4   1985-05-01  0.108317 -0.037589 -0.014148  1.000000
# ..         ...       ...       ...       ...       ...
# 283 2008-08-01  0.048075 -0.030916 -0.020934  1.860535
# 284 2008-09-01  0.047581 -0.037091 -0.018333  1.765637
# 285 2008-10-01  0.050582 -0.047106 -0.023478  1.762191
# 286 2008-11-01  0.040269 -0.039484 -0.020719  1.952470
# 287 2008-12-01  0.032006 -0.030909 -0.025704  1.617884
#
#                                                  Curve
# 0    NelsonSiegelCurve(beta0=0.11474328023846143, b...
# 1    NelsonSiegelCurve(beta0=0.12231479927121804, b...
# 2    NelsonSiegelCurve(beta0=0.11955865389731962, b...
# 3    NelsonSiegelCurve(beta0=0.11835021351660242, b...
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(curve_df['Beta0'])
ax.set_xlabel("Timesteps")
ax.set_ylabel("Value")
ax.set_title("Beta0")
plt.tight_layout()

# %%
beta0_adf_result = adfuller(curve_df['Beta0'])

print(f'ADF Statistic: {beta0_adf_result[0]}')
print(f'p-value: {beta0_adf_result[1]}')
# Out:
# ADF Statistic: -1.9649598802946247
# p-value: 0.30214506816288433

# %%
plot_acf(curve_df['Beta0'], lags=1, title="Lags=1")

plt.tight_layout()

# %%
plot_acf(curve_df['Beta0'], lags=12, title="Lags=12")

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(curve_df['Beta1'])
ax.set_xlabel("Timesteps")
ax.set_ylabel("Value")
ax.set_title("Beta1")
plt.tight_layout()

# %%
beta1_adf_result = adfuller(curve_df['Beta1'])

print(f'ADF Statistic: {beta1_adf_result[0]}')
print(f'p-value: {beta1_adf_result[1]}')
# Out:
# ADF Statistic: -3.9785713852050715
# p-value: 0.0015269691576233922

# %%
plot_acf(curve_df['Beta1'], lags=1, title="Lags=1")

plt.tight_layout()

# %%
plot_acf(curve_df['Beta1'], lags=12, title="Lags=12")

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(curve_df['Beta2'])
ax.set_xlabel("Timesteps")
ax.set_ylabel("Value")
ax.set_title("Beta2")
plt.tight_layout()

# %%
beta2_adf_result = adfuller(curve_df['Beta2'])

print(f'ADF Statistic: {beta2_adf_result[0]}')
print(f'p-value: {beta2_adf_result[1]}')
# Out:
# ADF Statistic: -3.0984869544289757
# p-value: 0.02666536344628287

# %%
plot_acf(curve_df['Beta2'], lags=1, title="Lags=1")

plt.tight_layout()

# %%
plot_acf(curve_df['Beta2'], lags=12, title="Lags=12")

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(curve_df['Tau'])
ax.set_xlabel("Timesteps")
ax.set_ylabel("Value")
ax.set_title("Beta2")
plt.tight_layout()

# %%
tau_adf_result = adfuller(curve_df['Tau'])

print(f'ADF Statistic: {tau_adf_result[0]}')
print(f'p-value: {tau_adf_result[1]}')
# Out:
# ADF Statistic: -2.885612498653646
# p-value: 0.047046831112549224

# %%
plot_acf(curve_df['Tau'], lags=1, title="Lags=1")

plt.tight_layout()

# %%
plot_acf(curve_df['Tau'], lags=12, title="Lags=12")

plt.tight_layout()
